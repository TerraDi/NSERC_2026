# %%
# !pip install pandas
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124
# Out:
# Looking in links: /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/gentoo2020/avx512, /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/gentoo/avx512, /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/gentoo2020/avx2, /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/gentoo/avx2, /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/gentoo2020/generic, /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/gentoo/generic, /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/generic
# Collecting pandas
#   Using cached pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Requirement already satisfied: numpy>=1.22.4 in /localscratch/dtian.50040805.0/env/lib/python3.10/site-packages (from pandas) (1.25.2+computecanada)
# Requirement already satisfied: python-dateutil>=2.8.2 in /localscratch/dtian.50040805.0/env/lib/python3.10/site-packages (from pandas) (2.9.0.post0+computecanada)
# Processing /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/generic/pytz-2026.2+computecanada-py3-none-any.whl (from pandas)
# Requirement already satisfied: tzdata>=2022.7 in /localscratch/dtian.50040805.0/env/lib/python3.10/site-packages (from pandas) (2026.2+computecanada)
# Requirement already satisfied: six>=1.5 in /localscratch/dtian.50040805.0/env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0+computecanada)
# Using cached pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
# Installing collected packages: pytz, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# Successfully installed pandas-2.3.3 pytz-2026.2+computecanada
# Looking in indexes: https://download.pytorch.org/whl/cu124
# Looking in links: /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/gentoo2020/avx512, /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/gentoo/avx512, /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/gentoo2020/avx2, /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/gentoo/avx2, /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/gentoo2020/generic, /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/gentoo/generic, /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/generic
# Requirement already satisfied: torch in /localscratch/dtian.50040805.0/env/lib/python3.10/site-packages (2.0.1+computecanada)
# Collecting torchvision
#   Using cached torchvision-0.21.0%2Bcu124-cp310-cp310-linux_x86_64.whl.metadata (6.1 kB)
# Collecting torchaudio
#   Using cached torchaudio-2.6.0%2Bcu124-cp310-cp310-linux_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: filelock in /localscratch/dtian.50040805.0/env/lib/python3.10/site-packages (from torch) (3.31.1+computecanada)
# Requirement already satisfied: typing-extensions in /localscratch/dtian.50040805.0/env/lib/python3.10/site-packages (from torch) (4.16.0+computecanada)
# Requirement already satisfied: sympy in /localscratch/dtian.50040805.0/env/lib/python3.10/site-packages (from torch) (1.14.0+computecanada)
# Requirement already satisfied: networkx in /localscratch/dtian.50040805.0/env/lib/python3.10/site-packages (from torch) (3.4.2+computecanada)
# Requirement already satisfied: jinja2 in /localscratch/dtian.50040805.0/env/lib/python3.10/site-packages (from torch) (3.1.6+computecanada)
# Requirement already satisfied: numpy in /localscratch/dtian.50040805.0/env/lib/python3.10/site-packages (from torchvision) (1.25.2+computecanada)
# Collecting torch
#   Using cached torch-2.6.0%2Bcu124-cp310-cp310-linux_x86_64.whl.metadata (28 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /localscratch/dtian.50040805.0/env/lib/python3.10/site-packages (from torchvision) (10.1.0+computecanada)
# Processing /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/generic/fsspec-2026.6.0+computecanada-py3-none-any.whl (from torch)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 265.2 MB/s  0:00:0200:0100:01
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 166.2 MB/s  0:00:0200:0100:01
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 219.8 MB/s  0:00:0000:0100:01
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 156.0 MB/s  0:00:00eta 0:00:01
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 101.4 MB/s  0:00:0100:0100:01
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 98.8 MB/s  0:00:02:00:0100:01
# Collecting nvidia-cusparselt-cu12==0.6.2 (from torch)
#   Using cached nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 102.0 MB/s  0:00:0100:0100:01
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch)
#   Using cached nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Processing /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/generic/triton-3.2.0+computecanada-cp310-cp310-linux_x86_64.whl (from torch)
# Processing /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/generic/sympy-1.13.1+computecanada-py3-none-any.whl (from torch)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /localscratch/dtian.50040805.0/env/lib/python3.10/site-packages (from sympy==1.13.1->torch) (1.3.0+computecanada)
# Requirement already satisfied: MarkupSafe>=2.0 in /localscratch/dtian.50040805.0/env/lib/python3.10/site-packages (from jinja2->torch) (2.1.5+computecanada)
# Using cached torchvision-0.21.0%2Bcu124-cp310-cp310-linux_x86_64.whl (7.3 MB)
# Downloading torch-2.6.0%2Bcu124-cp310-cp310-linux_x86_64.whl (768.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 768.4/768.4 MB 111.0 MB/s  0:00:050:00:0100:01
# Downloading nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl (150.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 66.4 MB/s  0:00:02m0:00:0100:01
# Using cached torchaudio-2.6.0%2Bcu124-cp310-cp310-linux_x86_64.whl (3.4 MB)
# Installing collected packages: triton, nvidia-cusparselt-cu12, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, fsspec, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchvision, torchaudio
#   Attempting uninstall: sympy━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/19 [nvidia-cusparselt-cu12]
#     Found existing installation: sympy 1.14.0+computecanada━━━  1/19 [nvidia-cusparselt-cu12]
#     Uninstalling sympy-1.14.0+computecanada:━━━━━━━━━━━━━━━━━━  1/19 [nvidia-cusparselt-cu12]
#       Successfully uninstalled sympy-1.14.0+computecanada━━━━━━━━━  2/19 [sympy]parselt-cu12]
#   Attempting uninstall: torch━━━━━━━━━━╸━━━━━━━━ 15/19 [nvidia-cusolver-cu12]2]
#     Found existing installation: torch 2.0.1+computecanada━━━━ 15/19 [nvidia-cusolver-cu12]
#     Uninstalling torch-2.0.1+computecanada:0m╸━━━━━━ 16/19 [torch]olver-cu12]
#       Successfully uninstalled torch-2.0.1+computecanada━━━━━━ 16/19 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19/19 [torchaudio]9 [torchaudio]]
# Successfully installed fsspec-2026.6.0+computecanada nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-cusparselt-cu12-0.6.2 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 sympy-1.13.1+computecanada torch-2.6.0+cu124 torchaudio-2.6.0+cu124 torchvision-0.21.0+cu124 triton-3.2.0+computecanada

# %%
import numpy as np
import matplotlib.pyplot as plt
import socket
print(socket.gethostname())
import torch
from torch import nn
from torch.utils.data import TensorDataset,DataLoader, Dataset
print("cuda available?", torch.cuda.is_available())
import scipy.linalg as linalg
import matplotlib.pyplot as plt
print(f"NumPy:  {np.__version__}")
print(f"PyTorch: {torch.__version__}")
import os
device = (
    "cuda" if torch.cuda.is_available()
    else "mps" if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
output_dir = "/home/dtian/scratch/Di_Research/CNN_Weights/CNN_1.5/"
# Out:
# fc10618
# cuda available? True
# NumPy:  1.25.2
# PyTorch: 2.6.0+cu124
# Using cuda device

# %%
trans_scin_range = (0.01,0.2)
AGN_scin_range = (0.00005,0.2)  ## replicates the observed variability fractions in CHILES VERDES
varbins = np.array([0,0.02,0.1]) ## fractional brightness fluctuation standard deviation. 0.1 Corresponds to a 10% RMS flux density fluctuation
varprobs = np.array([136/185,33/185,16/185]) ## correspond probabilities. Must sum to 1

### LOAD IN THE VARIABILITY: ###

#scinlib = np.load('/Users/dtian/Documents/Programming/Di_Research/Di_codefromFir/scintillation_library.npz')['varlib']
scinlib = np.load('/home/dtian/scratch/Di_Research/Di_codefromFir/scintillation_library.npz')['varlib']
#varlib = np.load('/Users/dtian/Documents/Programming/Di_Research/Di_codefromFir/variation_library.npz')['varlib']
varlib = np.load('/home/dtian/scratch/Di_Research/Di_codefromFir/variation_library.npz')['varlib']

# %%
#transientsdata = (np.load('/Users/dtian/Documents/Programming/Di_Research/Di_codefromFir/TDE_afterglows/ISM_profile/JettedTDE_ISM1.npz')['data'])[:,:,20]
transientsdata = (np.load('/home/dtian/scratch/Di_Research/Di_codefromFir/TDE_afterglows/ISM_profile/JettedTDE_ISM1.npz')['data'])[:,:,20]
transientsdata = np.append(transientsdata, (np.load('/home/dtian/scratch/Di_Research/Di_codefromFir/TDE_afterglows/wind_profile/JettedTDE_wind1.npz')['data'])[:,:,20], axis=0)
transientsdata = np.append(transientsdata, (np.load('/home/dtian/scratch/Di_Research/Di_codefromFir/TDE_afterglows/wind_profile/JettedTDE_wind2.npz')['data'])[:,:,20], axis=0)
transientsdata = np.append(transientsdata, (np.load('/home/dtian/scratch/Di_Research/Di_codefromFir/TDE_afterglows/wind_profile/JettedTDE_wind3.npz')['data'])[:,:,20], axis=0)
transientsdata = np.append(transientsdata, (np.load('/home/dtian/scratch/Di_Research/Di_codefromFir/GRB_afterglows/ISM_profile/GRB_ISM1.npz')['data'])[:,:,20], axis=0)
transientsdata = np.append(transientsdata, (np.load('/home/dtian/scratch/Di_Research/Di_codefromFir/GRB_afterglows/ISM_profile/GRB_ISM2.npz')['data'])[:,:,20], axis=0)
transientsdata = np.append(transientsdata, (np.load('/home/dtian/scratch/Di_Research/Di_codefromFir/GRB_afterglows/ISM_profile/GRB_ISM3.npz')['data'])[:,:,20], axis=0)
transientsdata = np.append(transientsdata, (np.load('/home/dtian/scratch/Di_Research/Di_codefromFir/GRB_afterglows/wind_profile/GRB_wind1.npz')['data'])[:,:,20], axis=0)
transientsdata = np.append(transientsdata, (np.load('/home/dtian/scratch/Di_Research/Di_codefromFir/GRB_afterglows/wind_profile/GRB_wind2.npz')['data'])[:,:,20], axis=0)
transientsdata = np.append(transientsdata, (np.load('/home/dtian/scratch/Di_Research/Di_codefromFir/GRB_afterglows/wind_profile/GRB_wind3.npz')['data'])[:,:,20], axis=0)
#transientsdata = np.append(transientsdata_1, transientsdata_2, transientsdata_3, transientsdata_4, transientsdata_5, transientsdata_6, transientsdata_7, transientsdata_8, transientsdata_9, transientsdata_10, axis=0)
print(transientsdata.shape)
# Out:
# (70000, 608)

# %%
def make_gaussian_heatmap(binary_target, sigma=2.0):
    """
    binary_target: (H, W) array with a few 1s at feature locations.
    returns:       (H, W) float heatmap, peaks = 1.0 at each feature.
    """
    H, W = binary_target.shape
    heatmap = np.zeros((H, W), dtype=np.float16) #changed from 32 originally

    # locations of the 1s
    ys, xs = np.nonzero(binary_target)

    # precompute kernel radius (3 sigma covers ~99% of the blob)
    radius = int(np.ceil(3 * sigma))

    for cy, cx in zip(ys, xs):
        # bounds of the patch to write into (clipped to image edges)
        y0, y1 = max(0, cy - radius), min(H, cy + radius + 1)
        x0, x1 = max(0, cx - radius), min(W, cx + radius + 1)

        yy, xx = np.mgrid[y0:y1, x0:x1]
        g = np.exp(-((yy - cy) ** 2 + (xx - cx) ** 2) / (2 * sigma ** 2))

        # max-combine so overlapping blobs stay <= 1
        heatmap[y0:y1, x0:x1] = np.maximum(heatmap[y0:y1, x0:x1], g)

    return heatmap

# %%
def gaussian2d(x,y,meanx,meany):

    FWHM = 5

    '''
    returns a 2d gaussian with the right shape
    '''

    return np.exp(-0.5*2.3**2*((x-meanx)**2+(y-meany)**2)/FWHM**2) # factor of 2.3 converts the FWHM to a standard deviation

def genbackground(xlen,ylen,tlen,Nbgnd,noiseamp=0.1):

    x = np.arange(xlen) ## x,y,t arrays
    y = np.arange(ylen)
    t = np.arange(tlen) 

    xx,yy,tt = np.meshgrid(x,y,t) ## create a grid of x,y positions to evaluate at

    #np.random.seed(41)
    rng = np.random.default_rng(123)
    
    noisefield = noiseamp*rng.standard_normal(size = (xlen,ylen,tlen)) # generate the noise

    backgroundfield = np.zeros(noisefield.shape) ## array for the transient layer to be created in
    
    x0 = [] ## these record the x, y, and time mean values for each transient signal
    y0 = [] ## these record the x, y, and time mean values for each transient signal
    positions = np.zeros((Nbgnd,2))

    for i in range(Nbgnd): ## for each background source

        x0.append(np.random.randint(xlen)) 
        y0.append(np.random.randint(ylen)) ## generate a uniform random map position

        bgfluxdensity = 10**(2*np.random.rand()-1) ## brightness, right now log-uniform between 0.1 and 10

        layer = bgfluxdensity*gaussian2d(xx,yy,x0[-1],y0[-1]) # add the map layer value

        ## apply intrinsic variability:

        idx = np.random.randint(2000)
        phase = np.random.randint(608)

        randfloat = np.random.rand()
        
        if randfloat <= varprobs[0]:
            amp = varbins[0]
        elif randfloat <= varprobs[0]+varprobs[1]:
            amp = varbins[1]
        else:
            amp = varbins[2]
        
        layer*= 1+amp*(varlib[idx][phase:])[np.newaxis,np.newaxis,:tlen]

        ## apply extrinsic variability:

        idx = np.random.randint(2000)
        phase = np.random.randint(608)
        amp = 10**((np.log10(AGN_scin_range[1]/AGN_scin_range[0]))*np.random.rand()+np.log10(AGN_scin_range[0]))
        #print(amp)

        layer*= 1+amp*(varlib[idx][phase:])[np.newaxis,np.newaxis,:tlen]

        backgroundfield += layer



    positions[:,0] = np.array(x0)
    positions[:,1] = np.array(y0)

    return backgroundfield,noisefield,positions
        
def gentransients(xlen,ylen,tlen,Ntrans):
    '''
    Return  transient_field:    100*100*608 transient field
            positions:          Ntrans * 2 transient positions
            gaussian_transient_map 100*100 2d-gaussian position of the transient
    '''

    global transientsdata
    #np.random.seed(41)
    x = np.arange(xlen) ## x and y arrays
    y = np.arange(ylen)
    t = np.arange(tlen) 

    xx,yy,tt = np.meshgrid(x,y,t) ## create a grid of x,y positions to evaluate at

    transient_field = np.zeros((xlen,ylen,tlen)) ## array for the transient layer to be created in
    
    x0 = [] ## these record the x, y, and time mean values for each transient signal
    y0 = [] ## these record the x, y, and time mean values for each transient signal
    positions = np.zeros((Ntrans,2))
    transient_map = np.zeros((xlen, ylen))

    for i in range(Ntrans):

        x0.append(np.random.randint(xlen))
        y0.append(np.random.randint(ylen))

        while True:
            LCidx = np.random.randint(70000)
            print("LCidx is: ", LCidx)
            LC = transientsdata[LCidx]
            if np.max(LC) != 0: break #This ensure np.max is no zero and eliminate Nan
        LC /= np.max(LC)
        transfluxdensity = 10**(np.random.rand()-0.5) ## right now log-uniform between 0.3 and 3 ## change as you see fit

        ## apply the shape of the lightcurve
        
        layer = transfluxdensity*gaussian2d(xx,yy,x0[-1],y0[-1])*LC[np.newaxis,np.newaxis,:tlen]

        ## apply extrinsic variability:

        idx = np.random.randint(2000)
        phase = np.random.randint(608)
        amp = 10**((np.log10(trans_scin_range[1]/trans_scin_range[0]))*np.random.rand()+np.log10(trans_scin_range[0]))
        #print(amp)

        layer*= 1+amp*(varlib[idx][phase:])[np.newaxis,np.newaxis,:tlen]

        transient_field += layer

        transient_map[y0[-1]][x0[-1]] = 1
    #gaussian_transient_map = make_gaussian_heatmap(transient_map)
    positions[:,0] = np.array(x0)
    positions[:,1] = np.array(y0)

    return transient_field,positions,transient_map

# %%
def genfields(Nfields=10, xlen=100, ylen=100, tlen=608, noiseamp=0.1, transient_toggle = True):
    '''
    Return: combined_field: Nfield * xlen * ylen * tlen, X input for NN
            target_maps:    Nfield * xlen * ylen, y for NN
            bgpositions:    Nfield * Nbgnd * 2, location of all background
            transientpositions: Nfield * Ntrans * 2, location of all transients

    '''
    combined_fields = np.empty((Nfields, xlen, ylen, tlen), dtype=np.float16)
    target_maps     = np.empty((Nfields, xlen, ylen),       dtype=np.float16)
    bgpositions, transientspositions = [], []

    for i in range(Nfields):
        print("Generating Image Index:", i)
        Nbgnd  = np.random.randint(200)
        if(transient_toggle):
            Ntrans = np.random.randint(5)
        else: 
            Ntrans = 0
        bg, noise, bgposition = genbackground(xlen, ylen, tlen, Nbgnd, noiseamp)
        transient, tpos, target_map = gentransients(xlen, ylen, tlen, Ntrans)

        combined_fields[i] = bg + noise + transient   # written in place, float32
        target_maps[i]     = target_map
        bgpositions.append(bgposition)
        transientspositions.append(tpos)
    #bgpositions = np.array(bgpositions)
    #transientspositions = np.array(transientspositions)
    return combined_fields, target_maps, bgpositions, transientspositions

# %%
def normalize_np(data, sample_frac=0.05, eps=1e-8):
    """
    Computes mean/std from a random subsample of `data` (cheap, statistically
    sufficient at this dataset size), then normalizes `data` in-place.
    Runs entirely on the original contiguous numpy array -- no torch,
    no permute -- so there's no ambiguity about whether a reduction over
    a huge strided view silently materializes a full-size temporary.
    """
    n = data.shape[0]
    sample_size = max(1, int(n * sample_frac))
    idx = np.random.choice(n, size=sample_size, replace=False)
    sample = data[idx].astype(np.float32)   # small, bounded copy just for stats
    mean = sample.mean()
    std  = sample.std()
    del sample

    data -= mean            # in-place on the big contiguous array, no new allocation
    data /= (std + eps)     # in-place, no new allocation
    return data, mean, std

def to_torch_nchw(data):
    """Convert an already-normalized NHWC numpy array into an NCHW torch view."""
    data = torch.from_numpy(data)   # no copy, shares the (already normalized) numpy memory
    data = data.squeeze(0)
    if data.dim() == 4:
        data = data.permute(0, 3, 1, 2)   # view only -- normalization is already done
    return data

# %%
X_start, y_start, _, _ = genfields(Nfields = 2)
# Out:
# Generating Image Index: 0
# Generating Image Index: 1
# LCidx is:  67827

# %%
for frame in range(101):
    plt.figure(figsize = (5,5))
    plt.imshow((X_start[0])[:,:,6*frame],vmax = 5,vmin = 0)
    plt.xticks([])
    plt.yticks([])
    #plt.savefig('/Users/dtian/Documents/Programming/Di_Research/example_animation/frame_%d.png' %frame)
    #plt.show()
    plt.close()

# %%
plt.figure(figsize = (5,5))
plt.imshow((y_start[0]),vmax = 1,vmin = 0)
plt.xticks([])
plt.yticks([])
plt.show()
plt.close()

# %%
def gaussianize_target(data, sigma=1):
    N, H, W = data.shape
    out = np.empty((N, H, W), dtype=np.float16)
    for i in range(N):
        out[i] = make_gaussian_heatmap(data[i], sigma)
    return out

# %%
y_start_gaussian = gaussianize_target(y_start, sigma=1)
plt.figure(figsize = (5,5))
plt.imshow((y_start_gaussian[0]),vmax = 1,vmin = 0)
plt.xticks([])
plt.yticks([])
plt.show()
plt.close()
#np.save(output_dir + "X_start.npy", X_start)

# %%
'''
X_test, y_test, bgspositions_test, transientspositions_test= genfields(Nfields=6000)
print(X_test.shape)
print(y_test.shape)
print(bgspositions_test[1].shape)
print(transientspositions_test[1].shape)
np.save(output_dir + "X_test.npy", X_test)
np.save(output_dir + "y_test.npy", y_test) 
np.savez(output_dir + "bgspositions_test.npy", *bgspositions_test)
np.savez(output_dir + "transientspositions_test.npy", *transientspositions_test)

print("Test?")
'''
# Out:
# '\nX_test, y_test, bgspositions_test, transientspositions_test= genfields(Nfields=6000)\nprint(X_test.shape)\nprint(y_test.shape)\nprint(bgspositions_test[1].shape)\nprint(transientspositions_test[1].shape)\nnp.save(output_dir + "X_test.npy", X_test)\nnp.save(output_dir + "y_test.npy", y_test) \nnp.savez(output_dir + "bgspositions_test.npy", *bgspositions_test)\nnp.savez(output_dir + "transientspositions_test.npy", *transientspositions_test)\n\nprint("Test?")\n'

# %%
X_train, y_train, bgspositions_train, transientspositions_train,= genfields(Nfields=24000)

np.save(output_dir + "X_train.npy", X_train)
np.save(output_dir + "y_train.npy", y_train)
np.savez(output_dir + "bgspositions_train.npy", *bgspositions_train)
np.savez(output_dir + "transientspositions_train.npy", *transientspositions_train)
# Out:
# Generating Image Index: 0
# LCidx is:  11626
# Generating Image Index: 1
# LCidx is:  44457
# Generating Image Index: 2
# LCidx is:  10044
# Generating Image Index: 3
# LCidx is:  26137
# LCidx is:  19380
# LCidx is:  48220
# LCidx is:  16606
# Generating Image Index: 4
# LCidx is:  2362
# Generating Image Index: 5
# Generating Image Index: 6
# LCidx is:  44341
# LCidx is:  56422
# LCidx is:  47470
# LCidx is:  64446
# Generating Image Index: 7
# LCidx is:  6978
# LCidx is:  31532
# Generating Image Index: 8
# LCidx is:  14827
# LCidx is:  8192
# Generating Image Index: 9
# LCidx is:  62332
# LCidx is:  33800
# LCidx is:  47102
# Generating Image Index: 10
# LCidx is:  31158
# Generating Image Index: 11
# LCidx is:  13677
# LCidx is:  16499
# Generating Image Index: 12
# LCidx is:  13176
# LCidx is:  53312
# Generating Image Index: 13
# LCidx is:  56833
# Generating Image Index: 14
# LCidx is:  16470
# LCidx is:  62347
# LCidx is:  2471
# Generating Image Index: 15
# Generating Image Index: 16
# LCidx is:  29006
# LCidx is:  9734
# LCidx is:  16765
# Generating Image Index: 17
# LCidx is:  15443
# LCidx is:  52282
# Generating Image Index: 18
# LCidx is:  27499
# LCidx is:  42242
# Generating Image Index: 19
# LCidx is:  51523
# Generating Image Index: 20
# LCidx is:  27404
# Generating Image Index: 21
# LCidx is:  17115
# LCidx is:  21174
# LCidx is:  55112
# Generating Image Index: 22
# LCidx is:  15936
# LCidx is:  47574
# Generating Image Index: 23
# LCidx is:  13269
# Generating Image Index: 24
# LCidx is:  46262
# LCidx is:  9382
# Generating Image Index: 25
# LCidx is:  21690
# LCidx is:  62067
# Generating Image Index: 26
# LCidx is:  60976
# LCidx is:  54895
# LCidx is:  344
# LCidx is:  39987
# Generating Image Index: 27
# LCidx is:  43219
# LCidx is:  37324
# LCidx is:  57047
# LCidx is:  31203
# Generating Image Index: 28
# LCidx is:  23508
# Generating Image Index: 29
# LCidx is:  66118
# Generating Image Index: 30
# LCidx is:  25034
# LCidx is:  31735
# LCidx is:  66899
# Generating Image Index: 31
# LCidx is:  69443
# LCidx is:  49441
# LCidx is:  60009
# LCidx is:  10199
# Generating Image Index: 32
# LCidx is:  36207
# LCidx is:  69364
# Generating Image Index: 33
# LCidx is:  51924
# LCidx is:  22711
# Generating Image Index: 34
# LCidx is:  46562
# LCidx is:  29180
# LCidx is:  58296
# Generating Image Index: 35
# LCidx is:  48032
# LCidx is:  14411
# LCidx is:  7030
# LCidx is:  5893
# Generating Image Index: 36
# LCidx is:  28827
# LCidx is:  53317
# Generating Image Index: 37
# Generating Image Index: 38
# LCidx is:  45753
# LCidx is:  20923
# LCidx is:  34752
# LCidx is:  60
# Generating Image Index: 39
# LCidx is:  33579
# LCidx is:  26936
# Generating Image Index: 40
# LCidx is:  17382
# LCidx is:  9616
# LCidx is:  48412
# Generating Image Index: 41
# LCidx is:  674
# Generating Image Index: 42
# LCidx is:  31076
# Generating Image Index: 43
# LCidx is:  28363
# Generating Image Index: 44
# LCidx is:  40691
# LCidx is:  65102
# Generating Image Index: 45
# LCidx is:  51474
# LCidx is:  28240
# LCidx is:  8998
# LCidx is:  66696
# Generating Image Index: 46
# Generating Image Index: 47
# LCidx is:  50142
# Generating Image Index: 48
# LCidx is:  63310
# LCidx is:  67092
# Generating Image Index: 49
# LCidx is:  67520
# Generating Image Index: 50
# LCidx is:  17320
# LCidx is:  30744
# Generating Image Index: 51
# Generating Image Index: 52
# Generating Image Index: 53
# LCidx is:  58534
# LCidx is:  34828
# Generating Image Index: 54
# LCidx is:  55747
# LCidx is:  27669
# LCidx is:  13314
# LCidx is:  27086
# Generating Image Index: 55
# Generating Image Index: 56
# Generating Image Index: 57
# Generating Image Index: 58
# LCidx is:  12140
# Generating Image Index: 59
# LCidx is:  14105
# LCidx is:  27044
# LCidx is:  17924
# LCidx is:  16177
# Generating Image Index: 60
# LCidx is:  33126
# Generating Image Index: 61
# LCidx is:  8716
# LCidx is:  23154
# LCidx is:  23989
# LCidx is:  31333
# Generating Image Index: 62
# Generating Image Index: 63
# LCidx is:  28241
# LCidx is:  33282
# LCidx is:  26065
# Generating Image Index: 64
# LCidx is:  60820
# LCidx is:  42639
# Generating Image Index: 65
# LCidx is:  28651
# LCidx is:  21312
# LCidx is:  60453
# Generating Image Index: 66
# LCidx is:  4403
# LCidx is:  27577
# LCidx is:  62864
# LCidx is:  64527
# Generating Image Index: 67
# LCidx is:  2966
# LCidx is:  30493
# Generating Image Index: 68
# Generating Image Index: 69
# LCidx is:  60644
# LCidx is:  53199
# Generating Image Index: 70
# LCidx is:  9566
# LCidx is:  2399
# LCidx is:  25235
# LCidx is:  22438
# Generating Image Index: 71
# LCidx is:  22341
# Generating Image Index: 72
# Generating Image Index: 73
# LCidx is:  13236
# LCidx is:  27060
# LCidx is:  10949
# Generating Image Index: 74
# LCidx is:  2065
# LCidx is:  20763
# LCidx is:  10127
# LCidx is:  63966
# Generating Image Index: 75
# LCidx is:  58921
# LCidx is:  63740
# LCidx is:  40563
# LCidx is:  56789
# Generating Image Index: 76
# LCidx is:  27615
# Generating Image Index: 77
# LCidx is:  65538
# LCidx is:  60447
# Generating Image Index: 78
# LCidx is:  14505
# Generating Image Index: 79
# LCidx is:  13968
# LCidx is:  28754
# LCidx is:  67497
# LCidx is:  41877
# Generating Image Index: 80
# LCidx is:  14395
# LCidx is:  52928
# Generating Image Index: 81
# LCidx is:  22900
# LCidx is:  43166
# Generating Image Index: 82
# LCidx is:  21721
# LCidx is:  48903
# Generating Image Index: 83
# LCidx is:  20775
# LCidx is:  14791
# LCidx is:  13157
# LCidx is:  45371
# Generating Image Index: 84
# LCidx is:  56673
# Generating Image Index: 85
# LCidx is:  9253
# LCidx is:  1190
# LCidx is:  24193
# LCidx is:  69220
# Generating Image Index: 86
# LCidx is:  65404
# Generating Image Index: 87
# LCidx is:  13120
# LCidx is:  66471
# LCidx is:  65325
# LCidx is:  38350
# Generating Image Index: 88
# LCidx is:  50410
# LCidx is:  2823
# LCidx is:  58363
# Generating Image Index: 89
# LCidx is:  44571
# LCidx is:  18384
# LCidx is:  36752
# Generating Image Index: 90
# LCidx is:  34913
# Generating Image Index: 91
# LCidx is:  36394
# LCidx is:  5958
# LCidx is:  41299
# LCidx is:  64914
# Generating Image Index: 92
# LCidx is:  39431
# LCidx is:  65868
# LCidx is:  54308
# LCidx is:  65619
# Generating Image Index: 93
# LCidx is:  23600
# LCidx is:  59578
# LCidx is:  34414
# Generating Image Index: 94
# LCidx is:  23756
# LCidx is:  65444
# Generating Image Index: 95
# LCidx is:  15674
# LCidx is:  14188
# LCidx is:  47883
# Generating Image Index: 96
# LCidx is:  34722
# LCidx is:  18251
# Generating Image Index: 97
# LCidx is:  65179
# LCidx is:  30610
# LCidx is:  51971
# LCidx is:  27194
# Generating Image Index: 98
# LCidx is:  65324
# LCidx is:  40522
# LCidx is:  66548
# LCidx is:  13823
# Generating Image Index: 99
# LCidx is:  10573
# LCidx is:  63901
# LCidx is:  30045
# Generating Image Index: 100
# LCidx is:  67249
# LCidx is:  37057
# LCidx is:  12314
# Generating Image Index: 101
# LCidx is:  54381
# LCidx is:  10731
# LCidx is:  26844
# Generating Image Index: 102
# LCidx is:  17036
# LCidx is:  37579
# LCidx is:  54784
# LCidx is:  9871
# Generating Image Index: 103
# LCidx is:  60892
# LCidx is:  49711
# Generating Image Index: 104
# LCidx is:  28213
# LCidx is:  998
# LCidx is:  11818
# LCidx is:  57836
# Generating Image Index: 105
# LCidx is:  66099
# LCidx is:  13751
# LCidx is:  10308
# Generating Image Index: 106
# LCidx is:  21462
# LCidx is:  48934
# LCidx is:  39844
# Generating Image Index: 107
# Generating Image Index: 108
# Generating Image Index: 109
# LCidx is:  39253
# LCidx is:  62074
# LCidx is:  22581
# LCidx is:  51005
# Generating Image Index: 110
# Generating Image Index: 111
# Generating Image Index: 112
# LCidx is:  40984
# LCidx is:  24724
# LCidx is:  36839
# LCidx is:  67735
# Generating Image Index: 113
# LCidx is:  18877
# LCidx is:  53446
# LCidx is:  560
# Generating Image Index: 114
# LCidx is:  193
# LCidx is:  65987
# LCidx is:  11491
# LCidx is:  62353
# Generating Image Index: 115
# LCidx is:  45543
# LCidx is:  27559
# LCidx is:  27294
# LCidx is:  46809
# Generating Image Index: 116
# LCidx is:  66339
# LCidx is:  6179
# Generating Image Index: 117
# LCidx is:  69982
# Generating Image Index: 118
# LCidx is:  8701
# Generating Image Index: 119
# LCidx is:  18952
# Generating Image Index: 120
# LCidx is:  38176
# Generating Image Index: 121
# Generating Image Index: 122
# Generating Image Index: 123
# Generating Image Index: 124
# LCidx is:  31769
# Generating Image Index: 125
# LCidx is:  10607
# LCidx is:  10148
# LCidx is:  42390
# LCidx is:  31066
# Generating Image Index: 126
# Generating Image Index: 127
# LCidx is:  1164
# Generating Image Index: 128
# LCidx is:  260
# LCidx is:  30017
# Generating Image Index: 129
# LCidx is:  34597
# LCidx is:  24451
# Generating Image Index: 130
# LCidx is:  26495
# LCidx is:  20147
# Generating Image Index: 131
# Generating Image Index: 132
# LCidx is:  8471
# LCidx is:  37169
# Generating Image Index: 133
# LCidx is:  68478
# Generating Image Index: 134
# LCidx is:  63356
# LCidx is:  31156
# LCidx is:  25274
# Generating Image Index: 135
# LCidx is:  38261
# LCidx is:  31814
# Generating Image Index: 136
# LCidx is:  14146
# Generating Image Index: 137
# LCidx is:  36671
# LCidx is:  5625
# LCidx is:  229
# Generating Image Index: 138
# LCidx is:  7963
# LCidx is:  67400
# Generating Image Index: 139
# LCidx is:  42093
# LCidx is:  17763
# LCidx is:  23271
# LCidx is:  16600
# Generating Image Index: 140
# LCidx is:  58260
# LCidx is:  14038
# LCidx is:  18523
# LCidx is:  1846
# Generating Image Index: 141
# LCidx is:  2010
# Generating Image Index: 142
# LCidx is:  45121
# LCidx is:  56333
# LCidx is:  31590
# LCidx is:  11127
# Generating Image Index: 143
# LCidx is:  13684
# LCidx is:  37737
# Generating Image Index: 144
# LCidx is:  46879
# Generating Image Index: 145
# LCidx is:  45862
# LCidx is:  26472
# Generating Image Index: 146
# LCidx is:  17085
# LCidx is:  68416
# Generating Image Index: 147
# LCidx is:  1980
# LCidx is:  12832
# LCidx is:  53602
# Generating Image Index: 148
# Generating Image Index: 149
# LCidx is:  24285
# LCidx is:  30412
# LCidx is:  21230
# Generating Image Index: 150
# LCidx is:  35339
# LCidx is:  53504
# LCidx is:  41325
# LCidx is:  63911
# Generating Image Index: 151
# LCidx is:  25542
# LCidx is:  63802
# Generating Image Index: 152
# LCidx is:  59934
# Generating Image Index: 153
# Generating Image Index: 154
# LCidx is:  22137
# LCidx is:  15283
# LCidx is:  29118
# LCidx is:  28494
# Generating Image Index: 155
# LCidx is:  25303
# LCidx is:  46154
# LCidx is:  58639
# Generating Image Index: 156
# LCidx is:  15314
# LCidx is:  38308
# LCidx is:  52049
# Generating Image Index: 157
# LCidx is:  9511
# LCidx is:  64451
# Generating Image Index: 158
# LCidx is:  58424
# LCidx is:  64351
# LCidx is:  6566
# Generating Image Index: 159
# LCidx is:  62342
# LCidx is:  56485
# LCidx is:  54546
# LCidx is:  66852
# Generating Image Index: 160
# LCidx is:  14809
# LCidx is:  1451
# Generating Image Index: 161
# LCidx is:  6332
# LCidx is:  60939
# Generating Image Index: 162
# LCidx is:  16539
# Generating Image Index: 163
# LCidx is:  50524
# LCidx is:  54224
# LCidx is:  58536
# Generating Image Index: 164
# LCidx is:  31016
# LCidx is:  44741
# Generating Image Index: 165
# LCidx is:  37402
# LCidx is:  12564
# LCidx is:  67988
# Generating Image Index: 166
# LCidx is:  54914
# LCidx is:  61882
# LCidx is:  14632
# LCidx is:  55818
# Generating Image Index: 167
# LCidx is:  7487
# LCidx is:  22667
# Generating Image Index: 168
# LCidx is:  24416
# LCidx is:  4040
# LCidx is:  19087
# Generating Image Index: 169
# LCidx is:  67110
# Generating Image Index: 170
# Generating Image Index: 171
# LCidx is:  39941
# LCidx is:  68175
# Generating Image Index: 172
# Generating Image Index: 173
# Generating Image Index: 174
# LCidx is:  37204
# LCidx is:  66234
# Generating Image Index: 175
# Generating Image Index: 176
# Generating Image Index: 177
# LCidx is:  18860
# LCidx is:  57492
# Generating Image Index: 178
# LCidx is:  11646
# Generating Image Index: 179
# Generating Image Index: 180
# LCidx is:  5361
# LCidx is:  50194
# LCidx is:  47395
# LCidx is:  7390
# Generating Image Index: 181
# LCidx is:  2525
# LCidx is:  15886
# LCidx is:  65915
# Generating Image Index: 182
# LCidx is:  44172
# LCidx is:  17679
# Generating Image Index: 183
# LCidx is:  67590
# LCidx is:  44312
# LCidx is:  35090
# LCidx is:  58169
# Generating Image Index: 184
# LCidx is:  50745
# Generating Image Index: 185
# LCidx is:  42994
# LCidx is:  29321
# Generating Image Index: 186
# LCidx is:  4285
# Generating Image Index: 187
# LCidx is:  3267
# LCidx is:  69284
# LCidx is:  26985
# LCidx is:  5496
# Generating Image Index: 188
# LCidx is:  46633
# LCidx is:  8987
# LCidx is:  24821
# Generating Image Index: 189
# Generating Image Index: 190
# LCidx is:  41081
# LCidx is:  56700
# LCidx is:  3921
# Generating Image Index: 191
# LCidx is:  60967
# Generating Image Index: 192
# LCidx is:  41814
# LCidx is:  44237
# Generating Image Index: 193
# LCidx is:  8142
# LCidx is:  22170
# LCidx is:  64930
# LCidx is:  16567
# Generating Image Index: 194
# LCidx is:  32630
# Generating Image Index: 195
# Generating Image Index: 196
# LCidx is:  62410
# LCidx is:  17718
# Generating Image Index: 197
# Generating Image Index: 198
# Generating Image Index: 199
# Generating Image Index: 200
# LCidx is:  33429
# LCidx is:  34107
# LCidx is:  23028
# Generating Image Index: 201
# LCidx is:  29829
# LCidx is:  40503
# Generating Image Index: 202
# LCidx is:  66526
# LCidx is:  42187
# Generating Image Index: 203
# Generating Image Index: 204
# LCidx is:  55753
# LCidx is:  13979
# LCidx is:  7045
# LCidx is:  48746
# Generating Image Index: 205
# LCidx is:  24788
# LCidx is:  68349
# Generating Image Index: 206
# LCidx is:  43042
# LCidx is:  9512
# LCidx is:  9237
# LCidx is:  41803
# Generating Image Index: 207
# LCidx is:  67543
# LCidx is:  29242
# LCidx is:  62610
# LCidx is:  25716
# Generating Image Index: 208
# LCidx is:  6172
# LCidx is:  44035
# LCidx is:  25891
# Generating Image Index: 209
# LCidx is:  63325
# LCidx is:  38332
# LCidx is:  47409
# LCidx is:  46757
# Generating Image Index: 210
# LCidx is:  56624
# Generating Image Index: 211
# LCidx is:  36919
# Generating Image Index: 212
# Generating Image Index: 213
# LCidx is:  42668
# Generating Image Index: 214
# Generating Image Index: 215
# Generating Image Index: 216
# LCidx is:  45487
# LCidx is:  47633
# LCidx is:  47659
# LCidx is:  11726
# Generating Image Index: 217
# LCidx is:  2547
# LCidx is:  44839
# Generating Image Index: 218
# LCidx is:  65507
# LCidx is:  55531
# LCidx is:  68823
# LCidx is:  60954
# Generating Image Index: 219
# Generating Image Index: 220
# LCidx is:  67012
# Generating Image Index: 221
# LCidx is:  37537
# LCidx is:  12328
# Generating Image Index: 222
# LCidx is:  42520
# LCidx is:  8290
# LCidx is:  23932
# Generating Image Index: 223
# LCidx is:  21722
# Generating Image Index: 224
# LCidx is:  16812
# LCidx is:  68823
# LCidx is:  13065
# LCidx is:  10995
# Generating Image Index: 225
# LCidx is:  32956
# LCidx is:  1607
# LCidx is:  17082
# Generating Image Index: 226
# LCidx is:  323
# LCidx is:  80
# LCidx is:  64681
# Generating Image Index: 227
# LCidx is:  39873
# LCidx is:  29184
# Generating Image Index: 228
# LCidx is:  66429
# LCidx is:  13202
# LCidx is:  58270
# Generating Image Index: 229
# LCidx is:  63958
# LCidx is:  11767
# LCidx is:  50858
# Generating Image Index: 230
# LCidx is:  33450
# LCidx is:  40251
# LCidx is:  42148
# LCidx is:  64310
# Generating Image Index: 231
# LCidx is:  2289
# LCidx is:  18714
# LCidx is:  6896
# LCidx is:  61232
# Generating Image Index: 232
# LCidx is:  34814
# LCidx is:  65652
# LCidx is:  24914
# Generating Image Index: 233
# LCidx is:  10742
# LCidx is:  857
# LCidx is:  53616
# LCidx is:  46485
# Generating Image Index: 234
# LCidx is:  42158
# LCidx is:  6486
# LCidx is:  11817
# Generating Image Index: 235
# LCidx is:  15323
# LCidx is:  2963
# LCidx is:  51865
# LCidx is:  47299
# Generating Image Index: 236
# LCidx is:  42034
# Generating Image Index: 237
# LCidx is:  5106
# LCidx is:  37584
# Generating Image Index: 238
# LCidx is:  10235
# LCidx is:  45348
# LCidx is:  16561
# Generating Image Index: 239
# Generating Image Index: 240
# LCidx is:  58277
# Generating Image Index: 241
# LCidx is:  11000
# LCidx is:  56976
# LCidx is:  18875
# LCidx is:  37158
# Generating Image Index: 242
# Generating Image Index: 243
# LCidx is:  33655
# LCidx is:  31414
# LCidx is:  67091
# LCidx is:  55441
# Generating Image Index: 244
# LCidx is:  44997
# LCidx is:  25033
# LCidx is:  12617
# LCidx is:  43839
# Generating Image Index: 245
# LCidx is:  28367
# LCidx is:  59342
# LCidx is:  16845
# LCidx is:  34943
# Generating Image Index: 246
# LCidx is:  52175
# LCidx is:  20974
# LCidx is:  34234
# Generating Image Index: 247
# LCidx is:  37452
# LCidx is:  40643
# LCidx is:  38252
# Generating Image Index: 248
# LCidx is:  62573
# LCidx is:  16926
# Generating Image Index: 249
# LCidx is:  58519
# LCidx is:  59552
# LCidx is:  21844
# LCidx is:  54699
# Generating Image Index: 250
# LCidx is:  8851
# Generating Image Index: 251
# LCidx is:  23852
# LCidx is:  48338
# LCidx is:  17769
# LCidx is:  67398
# Generating Image Index: 252
# LCidx is:  48104
# LCidx is:  638
# Generating Image Index: 253
# LCidx is:  45536
# LCidx is:  28619
# LCidx is:  45926
# Generating Image Index: 254
# LCidx is:  66867
# Generating Image Index: 255
# LCidx is:  17620
# Generating Image Index: 256
# LCidx is:  44764
# Generating Image Index: 257
# LCidx is:  52607
# Generating Image Index: 258
# LCidx is:  17149
# Generating Image Index: 259
# Generating Image Index: 260
# LCidx is:  3390
# LCidx is:  38683
# LCidx is:  39555
# LCidx is:  8540
# Generating Image Index: 261
# Generating Image Index: 262
# LCidx is:  60409
# LCidx is:  53339
# Generating Image Index: 263
# Generating Image Index: 264
# LCidx is:  43499
# Generating Image Index: 265
# LCidx is:  11392
# LCidx is:  67975
# LCidx is:  14715
# Generating Image Index: 266
# LCidx is:  52949
# LCidx is:  51206
# LCidx is:  69778
# Generating Image Index: 267
# Generating Image Index: 268
# Generating Image Index: 269
# LCidx is:  50094
# LCidx is:  57470
# LCidx is:  36618
# Generating Image Index: 270
# LCidx is:  31180
# LCidx is:  33170
# LCidx is:  62676
# Generating Image Index: 271
# LCidx is:  43541
# Generating Image Index: 272
# LCidx is:  13318
# LCidx is:  6727
# Generating Image Index: 273
# LCidx is:  3410
# LCidx is:  43144
# Generating Image Index: 274
# LCidx is:  6384
# LCidx is:  55470
# LCidx is:  4378
# Generating Image Index: 275
# LCidx is:  23828
# LCidx is:  12643
# LCidx is:  34722
# LCidx is:  52731
# Generating Image Index: 276
# LCidx is:  28240
# LCidx is:  14971
# Generating Image Index: 277
# LCidx is:  22717
# LCidx is:  14882
# Generating Image Index: 278
# Generating Image Index: 279
# LCidx is:  65538
# LCidx is:  65989
# LCidx is:  27448
# Generating Image Index: 280
# LCidx is:  5716
# LCidx is:  48469
# LCidx is:  21091
# LCidx is:  52212
# Generating Image Index: 281
# Generating Image Index: 282
# LCidx is:  24894
# LCidx is:  29110
# LCidx is:  60986
# Generating Image Index: 283
# Generating Image Index: 284
# Generating Image Index: 285
# LCidx is:  13330
# LCidx is:  54856
# LCidx is:  35641
# LCidx is:  12361
# LCidx is:  3483
# LCidx is:  5414
# LCidx is:  6140
# Generating Image Index: 288
# Generating Image Index: 289
# LCidx is:  38924
# LCidx is:  16786
# Generating Image Index: 290
# LCidx is:  65391
# LCidx is:  10196
# LCidx is:  48004
# LCidx is:  24987
# Generating Image Index: 291
# Generating Image Index: 292
# LCidx is:  39838
# Generating Image Index: 293
# LCidx is:  10768
# LCidx is:  69025
# Generating Image Index: 294
# LCidx is:  57914
# LCidx is:  3723
# LCidx is:  66711
# LCidx is:  28113
# Generating Image Index: 295
# Generating Image Index: 296
# LCidx is:  57167
# Generating Image Index: 1355
# LCidx is:  35181
# Generating Image Index: 1356
# LCidx is:  1976
# LCidx is:  42503
# Generating Image Index: 1357
# LCidx is:  2988
# Generating Image Index: 1358
# LCidx is:  50577
# LCidx is:  47610
# LCidx is:  56228
# Generating Image Index: 1359
# LCidx is:  10319
# LCidx is:  17178
# LCidx is:  45334
# LCidx is:  1324
# Generating Image Index: 1360
# LCidx is:  22439
# LCidx is:  58863
# LCidx is:  55495
# Generating Image Index: 1361
# Generating Image Index: 1362
# LCidx is:  64083
# Generating Image Index: 1363
# Generating Image Index: 1364
# LCidx is:  65448
# LCidx is:  23921
# LCidx is:  27047
# LCidx is:  21218
# Generating Image Index: 1365
# LCidx is:  17681
# LCidx is:  21180
# LCidx is:  20115
# Generating Image Index: 1366
# LCidx is:  57672
# LCidx is:  23344
# LCidx is:  48265
# Generating Image Index: 1367
# LCidx is:  67493
# Generating Image Index: 1368
# Generating Image Index: 1369
# LCidx is:  8613
# LCidx is:  62116
# LCidx is:  911
# Generating Image Index: 1370
# LCidx is:  58068
# LCidx is:  40614
# Generating Image Index: 1371
# LCidx is:  21176
# LCidx is:  11268
# LCidx is:  16108
# Generating Image Index: 1372
# LCidx is:  17441
# LCidx is:  50108
# LCidx is:  63881
# Generating Image Index: 1373
# LCidx is:  27863
# LCidx is:  55899
# Generating Image Index: 1374
# LCidx is:  67155
# LCidx is:  69142
# Generating Image Index: 1375
# LCidx is:  54011
# LCidx is:  60560
# LCidx is:  34755
# Generating Image Index: 1376
# LCidx is:  5252
# LCidx is:  26241
# LCidx is:  64732
# LCidx is:  60186
# Generating Image Index: 1377
# LCidx is:  37233
# LCidx is:  2527
# LCidx is:  8853
# Generating Image Index: 1378
# LCidx is:  42454
# Generating Image Index: 1379
# LCidx is:  33531
# Generating Image Index: 1380
# LCidx is:  24995
# LCidx is:  60258
# LCidx is:  47610
# Generating Image Index: 1381
# LCidx is:  10103
# LCidx is:  65364
# Generating Image Index: 1382
# LCidx is:  37501
# LCidx is:  52965
# LCidx is:  52874
# LCidx is:  21755
# Generating Image Index: 1383
# LCidx is:  3199
# LCidx is:  56838
# LCidx is:  20351
# LCidx is:  60734
# Generating Image Index: 1384
# LCidx is:  25171
# LCidx is:  16420
# LCidx is:  1278
# Generating Image Index: 1385
# Generating Image Index: 1386
# LCidx is:  35688
# Generating Image Index: 1387
# LCidx is:  3231
# LCidx is:  7611
# Generating Image Index: 1388
# LCidx is:  580
# LCidx is:  56920
# LCidx is:  60019
# LCidx is:  57170
# LCidx is:  40027
# Generating Image Index: 1389
# LCidx is:  33347
# LCidx is:  63298
# LCidx is:  6509
# Generating Image Index: 1390
# LCidx is:  19213
# LCidx is:  64719
# LCidx is:  11121
# LCidx is:  66869
# Generating Image Index: 1391
# LCidx is:  52897
# LCidx is:  67919
# LCidx is:  66641
# LCidx is:  10689
# Generating Image Index: 1392
# LCidx is:  26992
# LCidx is:  6503
# LCidx is:  54000
# LCidx is:  26285
# Generating Image Index: 1393
# LCidx is:  62447
# LCidx is:  16208
# LCidx is:  55234
# Generating Image Index: 1394
# LCidx is:  11263
# Generating Image Index: 1395
# Generating Image Index: 1396
# LCidx is:  46715
# LCidx is:  53705
# LCidx is:  25199
# Generating Image Index: 1397
# Generating Image Index: 1398
# Generating Image Index: 1399
# Generating Image Index: 1400
# LCidx is:  22657
# Generating Image Index: 1401
# LCidx is:  44228
# LCidx is:  15340
# LCidx is:  15789
# Generating Image Index: 1402
# Generating Image Index: 1403
# LCidx is:  6295
# Generating Image Index: 1404
# LCidx is:  23408
# LCidx is:  52274
# LCidx is:  1529
# LCidx is:  10292
# Generating Image Index: 1405
# LCidx is:  34438
# LCidx is:  33444
# LCidx is:  410
# Generating Image Index: 1406
# Generating Image Index: 1407
# LCidx is:  54525
# LCidx is:  56015
# LCidx is:  31382
# Generating Image Index: 1408
# LCidx is:  66024
# LCidx is:  63063
# LCidx is:  24919
# LCidx is:  33645
# Generating Image Index: 1409
# LCidx is:  34668
# LCidx is:  65628
# LCidx is:  28476
# LCidx is:  53162
# Generating Image Index: 1410
# LCidx is:  22541
# Generating Image Index: 1411
# LCidx is:  43539
# LCidx is:  60193
# LCidx is:  10378
# LCidx is:  13006
# Generating Image Index: 1412
# LCidx is:  49751
# LCidx is:  39168
# Generating Image Index: 1413
# Generating Image Index: 1414
# LCidx is:  41328
# Generating Image Index: 1415
# LCidx is:  46035
# LCidx is:  3627
# LCidx is:  7948
# LCidx is:  31323
# Generating Image Index: 1416
# LCidx is:  25098
# LCidx is:  16112
# LCidx is:  51415
# Generating Image Index: 1417
# LCidx is:  40628
# LCidx is:  10947
# Generating Image Index: 1418
# LCidx is:  55400
# LCidx is:  69633
# LCidx is:  59713
# LCidx is:  16502
# Generating Image Index: 1419
# LCidx is:  29655
# LCidx is:  35522
# LCidx is:  10384
# Generating Image Index: 1420
# Generating Image Index: 1421
# Generating Image Index: 1422
# LCidx is:  5250
# Generating Image Index: 1423
# LCidx is:  40762
# LCidx is:  52663
# LCidx is:  2619
# Generating Image Index: 1424
# LCidx is:  27302
# LCidx is:  21564
# LCidx is:  66988
# Generating Image Index: 1425
# LCidx is:  56838
# LCidx is:  12856
# LCidx is:  61467
# LCidx is:  38129
# Generating Image Index: 1426
# LCidx is:  30126
# Generating Image Index: 1427
# LCidx is:  35477
# LCidx is:  15109
# Generating Image Index: 1428
# LCidx is:  57868
# Generating Image Index: 1429
# Generating Image Index: 1430
# Generating Image Index: 1431
# LCidx is:  14536
# LCidx is:  62290
# LCidx is:  34401
# Generating Image Index: 1432
# Generating Image Index: 1433
# Generating Image Index: 1434
# LCidx is:  60462
# LCidx is:  12351
# Generating Image Index: 1435
# LCidx is:  62641
# LCidx is:  11771
# LCidx is:  35657
# LCidx is:  50742
# Generating Image Index: 1436
# Generating Image Index: 1437
# LCidx is:  64188
# LCidx is:  17451
# LCidx is:  62213
# Generating Image Index: 1438
# Generating Image Index: 1439
# LCidx is:  26680
# LCidx is:  43734
# Generating Image Index: 1440
# Generating Image Index: 1441
# LCidx is:  50660
# LCidx is:  27462
# LCidx is:  40519
# Generating Image Index: 1442
# LCidx is:  56521
# LCidx is:  64785
# LCidx is:  22484
# Generating Image Index: 1443
# LCidx is:  31594
# LCidx is:  27963
# LCidx is:  64444
# Generating Image Index: 1444
# LCidx is:  50982
# LCidx is:  53186
# Generating Image Index: 1445
# LCidx is:  69194
# Generating Image Index: 1446
# LCidx is:  26047
# LCidx is:  9745
# LCidx is:  22909
# Generating Image Index: 1447
# LCidx is:  23699
# LCidx is:  38422
# LCidx is:  19916
# Generating Image Index: 1448
# Generating Image Index: 1449
# Generating Image Index: 1450
# LCidx is:  9250
# LCidx is:  41784
# LCidx is:  5227
# LCidx is:  44964
# Generating Image Index: 1451
# LCidx is:  16989
# LCidx is:  11272
# LCidx is:  8311
# Generating Image Index: 1452
# LCidx is:  20925
# LCidx is:  24827
# LCidx is:  62175
# Generating Image Index: 1453
# LCidx is:  68256
# Generating Image Index: 1454
# Generating Image Index: 1455
# LCidx is:  21206
# Generating Image Index: 1456
# LCidx is:  31430
# LCidx is:  32761
# LCidx is:  52629
# Generating Image Index: 1457
# Generating Image Index: 1458
# LCidx is:  42965
# LCidx is:  42044
# Generating Image Index: 1459
# LCidx is:  19749
# LCidx is:  10559
# LCidx is:  13264
# LCidx is:  42232
# Generating Image Index: 1460
# LCidx is:  43012
# Generating Image Index: 1461
# LCidx is:  12419
# LCidx is:  24777
# Generating Image Index: 1462
# LCidx is:  53913
# Generating Image Index: 1463
# LCidx is:  30745
# LCidx is:  50908
# LCidx is:  43342
# Generating Image Index: 1464
# Generating Image Index: 1465
# LCidx is:  36382
# LCidx is:  12392
# Generating Image Index: 1466
# LCidx is:  27770
# Generating Image Index: 1467
# LCidx is:  45894
# LCidx is:  47729
# LCidx is:  42426
# Generating Image Index: 1468
# LCidx is:  50646
# LCidx is:  41554
# LCidx is:  36131
# Generating Image Index: 1469
# LCidx is:  22541
# LCidx is:  68856
# LCidx is:  6685
# Generating Image Index: 1470
# LCidx is:  13914
# LCidx is:  20977
# LCidx is:  52099
# Generating Image Index: 1471
# Generating Image Index: 1472
# LCidx is:  52516
# LCidx is:  37500
# LCidx is:  13465
# Generating Image Index: 1473
# LCidx is:  42854
# LCidx is:  9042
# Generating Image Index: 1474
# LCidx is:  27581
# LCidx is:  12337
# LCidx is:  58759
# Generating Image Index: 1475
# LCidx is:  24650
# LCidx is:  61280
# Generating Image Index: 1476
# LCidx is:  44707
# LCidx is:  60350
# LCidx is:  2081
# LCidx is:  67632
# Generating Image Index: 1477
# LCidx is:  69235
# LCidx is:  3652
# Generating Image Index: 1478
# LCidx is:  13343
# Generating Image Index: 1479
# LCidx is:  41591
# Generating Image Index: 1480
# Generating Image Index: 1481
# LCidx is:  6531
# LCidx is:  19780
# Generating Image Index: 1482
# LCidx is:  4632
# Generating Image Index: 1483
# LCidx is:  57253
# LCidx is:  20977
# Generating Image Index: 1484
# Generating Image Index: 1485
# LCidx is:  59920
# LCidx is:  65678
# LCidx is:  10356
# LCidx is:  43494
# Generating Image Index: 1486
# Generating Image Index: 1487
# LCidx is:  62494
# LCidx is:  59409
# LCidx is:  25152
# LCidx is:  10455
# Generating Image Index: 1488
# LCidx is:  39608
# LCidx is:  34977
# LCidx is:  37088
# LCidx is:  51347
# Generating Image Index: 1489
# Generating Image Index: 1490
# LCidx is:  57379
# LCidx is:  10936
# Generating Image Index: 1491
# LCidx is:  19776
# Generating Image Index: 1492
# LCidx is:  21663
# LCidx is:  51608
# LCidx is:  59779
# Generating Image Index: 1493
# Generating Image Index: 1494
# LCidx is:  66441
# LCidx is:  58145
# Generating Image Index: 1495
# LCidx is:  38682
# LCidx is:  46455
# Generating Image Index: 1496
# LCidx is:  63471
# LCidx is:  41079
# LCidx is:  62064
# Generating Image Index: 1497
# LCidx is:  57493
# LCidx is:  7583
# LCidx is:  17877
# Generating Image Index: 1498
# Generating Image Index: 1499
# LCidx is:  62339
# LCidx is:  18944
# Generating Image Index: 1500
# Generating Image Index: 1501
# LCidx is:  43929
# LCidx is:  6501
# LCidx is:  69156
# LCidx is:  65381
# Generating Image Index: 1502
# LCidx is:  48911
# LCidx is:  28871
# Generating Image Index: 1503
# Generating Image Index: 1504
# LCidx is:  14117
# LCidx is:  48770
# Generating Image Index: 1505
# Generating Image Index: 1506
# LCidx is:  28451
# LCidx is:  24679
# Generating Image Index: 1507
# Generating Image Index: 1508
# LCidx is:  19288
# LCidx is:  12758
# LCidx is:  69777
# LCidx is:  40543
# Generating Image Index: 1509
# LCidx is:  68084
# LCidx is:  1765
# LCidx is:  42148
# Generating Image Index: 1510
# LCidx is:  15521
# LCidx is:  6621
# LCidx is:  28115
# Generating Image Index: 1511
# LCidx is:  26842
# LCidx is:  25388
# LCidx is:  69455
# LCidx is:  24908
# Generating Image Index: 1512
# Generating Image Index: 1513
# LCidx is:  64119
# LCidx is:  68973
# Generating Image Index: 1514
# LCidx is:  47629
# LCidx is:  54338
# LCidx is:  68585
# LCidx is:  65329
# Generating Image Index: 1515
# Generating Image Index: 1516
# Generating Image Index: 1517
# LCidx is:  30463
# LCidx is:  24790
# LCidx is:  18396
# Generating Image Index: 1518
# Generating Image Index: 1519
# LCidx is:  27092
# Generating Image Index: 1520
# LCidx is:  33163
# LCidx is:  5772
# Generating Image Index: 1521
# LCidx is:  45302
# LCidx is:  59968
# Generating Image Index: 1522
# Generating Image Index: 1523
# Generating Image Index: 1524
# LCidx is:  15723
# LCidx is:  46787
# LCidx is:  11012
# LCidx is:  31028
# Generating Image Index: 1525
# Generating Image Index: 1526
# Generating Image Index: 1527
# LCidx is:  64769
# LCidx is:  35461
# LCidx is:  19883
# LCidx is:  53937
# Generating Image Index: 1528
# LCidx is:  63351
# Generating Image Index: 1529
# LCidx is:  30557
# LCidx is:  65523
# LCidx is:  59178
# Generating Image Index: 1530
# LCidx is:  40789
# Generating Image Index: 1531
# LCidx is:  20836
# Generating Image Index: 1532
# LCidx is:  45125
# LCidx is:  2742
# LCidx is:  50805
# LCidx is:  41700
# Generating Image Index: 1533
# LCidx is:  40943
# LCidx is:  17871
# LCidx is:  39801
# Generating Image Index: 1534
# Generating Image Index: 1535
# LCidx is:  43625
# LCidx is:  24660
# Generating Image Index: 1536
# LCidx is:  52739
# LCidx is:  45200
# LCidx is:  59304
# Generating Image Index: 1537
# LCidx is:  1816
# LCidx is:  42342
# LCidx is:  32320
# LCidx is:  17147
# Generating Image Index: 1538
# Generating Image Index: 1539
# LCidx is:  49211
# LCidx is:  53645
# LCidx is:  51160
# Generating Image Index: 1540
# LCidx is:  35440
# Generating Image Index: 1541
# LCidx is:  11228
# LCidx is:  64335
# Generating Image Index: 1542
# LCidx is:  18045
# Generating Image Index: 1543
# LCidx is:  48760
# LCidx is:  45527
# LCidx is:  51802
# Generating Image Index: 1544
# LCidx is:  63315
# LCidx is:  44842
# Generating Image Index: 1545
# LCidx is:  54875
# LCidx is:  65455
# LCidx is:  39233
# LCidx is:  56451
# Generating Image Index: 1546
# LCidx is:  41086
# LCidx is:  18263
# Generating Image Index: 1547
# LCidx is:  28085
# LCidx is:  26092
# LCidx is:  955
# Generating Image Index: 1548
# Generating Image Index: 1549
# LCidx is:  36218
# LCidx is:  42331
# Generating Image Index: 1550
# LCidx is:  59274
# LCidx is:  37585
# LCidx is:  12535
# LCidx is:  69065
# Generating Image Index: 1551
# Generating Image Index: 1552
# LCidx is:  5088
# LCidx is:  67392
# LCidx is:  38537
# LCidx is:  51941
# Generating Image Index: 1553
# LCidx is:  39796
# LCidx is:  190
# LCidx is:  14842
# Generating Image Index: 1554
# LCidx is:  7466
# LCidx is:  69523
# LCidx is:  6976
# LCidx is:  63550
# Generating Image Index: 1555
# LCidx is:  10800
# Generating Image Index: 1556
# LCidx is:  26757
# LCidx is:  19575
# LCidx is:  29230
# LCidx is:  9484
# Generating Image Index: 1557
# Generating Image Index: 1558
# LCidx is:  556
# LCidx is:  34015
# Generating Image Index: 1559
# LCidx is:  64161
# LCidx is:  68352
# Generating Image Index: 1560
# LCidx is:  55649
# LCidx is:  43011
# Generating Image Index: 1561
# Generating Image Index: 1562
# LCidx is:  19486
# LCidx is:  62676
# Generating Image Index: 1563
# LCidx is:  5306
# LCidx is:  31859
# LCidx is:  42697
# Generating Image Index: 1564
# Generating Image Index: 1565
# LCidx is:  3676
# Generating Image Index: 1566
# Generating Image Index: 1567
# LCidx is:  47130
# LCidx is:  33311
# LCidx is:  19164
# LCidx is:  32374
# Generating Image Index: 1568
# LCidx is:  50634
# LCidx is:  23303
# LCidx is:  17007
# Generating Image Index: 1569
# LCidx is:  30744
# LCidx is:  27702
# LCidx is:  11272
# LCidx is:  40961
# Generating Image Index: 1570
# LCidx is:  55427
# Generating Image Index: 1571
# Generating Image Index: 1572
# Generating Image Index: 1573
# Generating Image Index: 1574
# Generating Image Index: 1575
# LCidx is:  46254
# LCidx is:  59151
# Generating Image Index: 1576
# LCidx is:  64654
# LCidx is:  52735
# LCidx is:  42622
# Generating Image Index: 1577
# LCidx is:  45905
# LCidx is:  13969
# Generating Image Index: 1578
# LCidx is:  28775
# LCidx is:  9849
# LCidx is:  7541
# LCidx is:  3772
# Generating Image Index: 1579
# LCidx is:  8935
# LCidx is:  45307
# LCidx is:  43712
# Generating Image Index: 1580
# LCidx is:  19522
# LCidx is:  13812
# Generating Image Index: 1581
# LCidx is:  52900
# LCidx is:  52609
# LCidx is:  13027
# Generating Image Index: 1582
# LCidx is:  18484
# LCidx is:  44464
# Generating Image Index: 1583
# LCidx is:  49039
# LCidx is:  35068
# Generating Image Index: 1584
# LCidx is:  32702
# LCidx is:  59570
# LCidx is:  65015
# LCidx is:  36167
# Generating Image Index: 1585
# LCidx is:  33885
# Generating Image Index: 1586
# LCidx is:  21430
# LCidx is:  14276
# LCidx is:  56250
# LCidx is:  24328
# Generating Image Index: 1587
# LCidx is:  44584
# LCidx is:  21353
# Generating Image Index: 1588
# LCidx is:  19417
# Generating Image Index: 1589
# LCidx is:  8052
# Generating Image Index: 1590
# LCidx is:  12878
# Generating Image Index: 1591
# LCidx is:  33810
# LCidx is:  35673
# LCidx is:  40962
# LCidx is:  66678
# Generating Image Index: 1592
# LCidx is:  65785
# LCidx is:  49569
# Generating Image Index: 1593
# Generating Image Index: 1594
# LCidx is:  69919
# LCidx is:  30489
# Generating Image Index: 1595
# LCidx is:  58682
# LCidx is:  35940
# LCidx is:  8122
# LCidx is:  25472
# Generating Image Index: 1596
# LCidx is:  38610
# LCidx is:  34616
# LCidx is:  55959
# Generating Image Index: 1597
# LCidx is:  54961
# LCidx is:  1961
# LCidx is:  66377
# Generating Image Index: 1598
# LCidx is:  49868
# LCidx is:  35347
# LCidx is:  39585
# Generating Image Index: 1599
# Generating Image Index: 1600
# LCidx is:  26865
# LCidx is:  43922
# LCidx is:  24957
# LCidx is:  50407
# Generating Image Index: 1601
# LCidx is:  39435
# Generating Image Index: 1602
# LCidx is:  55117
# LCidx is:  22802
# Generating Image Index: 1603
# LCidx is:  31716
# LCidx is:  1472
# Generating Image Index: 1604
# Generating Image Index: 1605
# Generating Image Index: 1606
# LCidx is:  66099
# LCidx is:  62146
# LCidx is:  51176
# Generating Image Index: 1607
# LCidx is:  56683
# LCidx is:  69968
# LCidx is:  62371
# LCidx is:  32871
# Generating Image Index: 1608
# LCidx is:  25057
# LCidx is:  38288
# Generating Image Index: 1609
# LCidx is:  31482
# LCidx is:  42136
# LCidx is:  44276
# LCidx is:  10632
# Generating Image Index: 1610
# LCidx is:  31410
# LCidx is:  55392
# Generating Image Index: 1611
# LCidx is:  20542
# LCidx is:  12178
# LCidx is:  2659
# LCidx is:  32261
# Generating Image Index: 1612
# LCidx is:  66645
# LCidx is:  9859
# Generating Image Index: 1613
# LCidx is:  48578
# LCidx is:  1663
# Generating Image Index: 1614
# LCidx is:  19321
# Generating Image Index: 1615
# Generating Image Index: 1616
# LCidx is:  23984
# LCidx is:  10845
# LCidx is:  36454
# LCidx is:  24555
# Generating Image Index: 1617
# Generating Image Index: 1618
# Generating Image Index: 1619
# LCidx is:  19887
# LCidx is:  1390
# Generating Image Index: 1620
# LCidx is:  49247
# LCidx is:  38010
# LCidx is:  27330
# Generating Image Index: 1621
# Generating Image Index: 1622
# Generating Image Index: 1623
# LCidx is:  41439
# LCidx is:  10896
# LCidx is:  27280
# Generating Image Index: 1624
# LCidx is:  6742
# Generating Image Index: 1625
# LCidx is:  47936
# Generating Image Index: 1626
# Generating Image Index: 1627

# %%
X_test = np.load(output_dir + "X_test.npy")
y_test = np.load(output_dir + "y_test.npy")
print("X_train  nan:", np.isnan(X_train).any().item(),  "inf:", np.isinf(X_train).any().item())
print("y_train  nan:", np.isnan(y_train).any().item(),  "inf:", np.isinf(y_train).any().item())
print("X_test  nan:", np.isnan(X_test).any().item(),  "inf:", np.isinf(X_test).any().item())
print("y_test  nan:", np.isnan(y_test).any().item(),  "inf:", np.isinf(y_test).any().item())
X_test, x_test_mean, x_test_std = normalize_np(X_test)
X_test = to_torch_nchw(X_test)

y_test_gaussian = gaussianize_target(y_test, sigma=1)
y_test_gaussian, _, _ = normalize_np(y_test_gaussian)
y_test_gaussian = to_torch_nchw(y_test_gaussian)
print(X_test.shape)
print(y_test.shape)
print(y_test_gaussian.shape)

# %%
X_train = np.load(output_dir + "X_train.npy")
print("X_train loaded Reached here?")
y_train = np.load(output_dir + "y_train.npy")
print("Reached here?")
X_train, x_train_mean, x_train_std = normalize_np(X_train)
print("Reached here?")
X_train = to_torch_nchw(X_train)
print("Reached here?")

y_train_gaussian = gaussianize_target(y_train, sigma=1)
y_train_gaussian, y_train_mean, y_train_std = normalize_np(y_train_gaussian)
y_train_gaussian = to_torch_nchw(y_train_gaussian)
print("Reached here?")
print("y_train_mean is", y_train_mean)
print("y_train_std is", y_train_std)
print(X_train.shape)
print(y_train.shape)
print(y_train_gaussian.shape)

# %%
train_dataset = TensorDataset(X_train, y_train_gaussian)
test_dataset  = TensorDataset(X_test,  y_test_gaussian)

batch_size = 128

train_dataloader = DataLoader(train_dataset, batch_size=128, shuffle=True)
test_dataloader  = DataLoader(test_dataset,  batch_size=256, shuffle=False)

# %%
class ResBlock(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv2d(channels, channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(channels),
            nn.ReLU(),
            nn.Conv2d(channels, channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(channels),
        )
        self.relu = nn.ReLU()

    def forward(self, x):
        return self.relu(x + self.block(x))


class HeatmapNet(nn.Module):
    """
    Input:  (N, 608, 100, 100)
    Output: (N, 100, 100)
    """
    def __init__(self, tlen=608):
        super().__init__()
        self.enlarge1 = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=False)  # -> 200x200

        # Encode
        self.stem = nn.Sequential(
            nn.Conv2d(tlen, 96, 15, padding=7), nn.BatchNorm2d(96), nn.ReLU(),
        )                                                  # (N, 96, 200, 200)
        self.enc1  = nn.Sequential(ResBlock(96), ResBlock(96))
        self.down1 = nn.MaxPool2d(2)                       # -> 100x100

        self.enc2  = nn.Sequential(
            nn.Conv2d(96, 192, 3, padding=1), nn.BatchNorm2d(192), nn.ReLU(),
            ResBlock(192), ResBlock(192),
        )                                                  # (N, 192, 100, 100)
        self.down2 = nn.MaxPool2d(2)                       # -> 50x50

        self.enc3  = nn.Sequential(
            nn.Conv2d(192, 384, 3, padding=1), nn.BatchNorm2d(384), nn.ReLU(),  # FIX 1: in-channels 96 -> 192
            ResBlock(384), ResBlock(384),
        )                                                  # (N, 384, 50, 50)
        self.down3 = nn.MaxPool2d(2)                       # -> 25x25

        self.bottleneck = nn.Sequential(
            nn.Conv2d(384, 768, 3, padding=1), nn.BatchNorm2d(768), nn.ReLU(),
            ResBlock(768), ResBlock(768),
        )                                                  # (N, 768, 25, 25)

        # Decode
        self.up2  = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=False)  # 25 -> 50
        self.dec2 = nn.Sequential(
            nn.Conv2d(768 + 384, 192, 3, padding=1), nn.BatchNorm2d(192), nn.ReLU(),   # in: 768(up)+384(e3 skip)=1152
            ResBlock(192),
        )
        self.up1  = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=False)  # 50 -> 100
        self.dec1 = nn.Sequential(
            nn.Conv2d(192 + 192, 96, 3, padding=1), nn.BatchNorm2d(96), nn.ReLU(),      # FIX 4: 192+96 -> 192+192 (e2 skip has 192 ch)
            ResBlock(96),
        )

        self.head = nn.Conv2d(96, 1, 1)                    # 1-channel logits

    def forward(self, x):
        pre_enlarge = self.enlarge1(x)          # 200x200
        s  = self.stem(pre_enlarge)             # 200x200, 96
        e1 = self.enc1(s)                       # 200x200, 96
        e2 = self.enc2(self.down1(e1))          # 100x100, 192
        e3 = self.enc3(self.down2(e2))          # 50x50,  384
        b  = self.bottleneck(self.down3(e3))    # 25x25,  768   FIX 2: down2 -> down3

        d2 = self.dec2(torch.cat([self.up2(b),  e3], dim=1))  # 50x50   FIX 3: skip e2 -> e3
        d1 = self.dec1(torch.cat([self.up1(d2), e2], dim=1))  # 100x100 FIX 3: skip e1 -> e2
        return self.head(d1).squeeze(1)         # (N, 100, 100)

# %%
'''
The hungarian_loss take account the fact that two similar transient 3D image, (A, B, C) and (B, A, C), would be similar but with differnent loss
Hungarian_loss take care of it and make them similar loss
'''

from scipy.optimize import linear_sum_assignment
import torch.nn.functional as F

def hungarian_loss(pred, target):
    # pred, target: (N, n_trans, n_params)
    batch_size, n_trans = pred.shape[:2]
    losses = []

    for i in range(batch_size):
        cost = torch.stack([
            torch.stack([F.mse_loss(pred[i, j], target[i, k])
                         for k in range(n_trans)])
            for j in range(n_trans)
        ])
        row_ind, col_ind = linear_sum_assignment(cost.detach().cpu().numpy())
        matched = cost[row_ind, col_ind].sum()   # advanced indexing, stays on GPU, keeps grad
        losses.append(matched / n_trans)

    return torch.stack(losses).mean()

# %%
model = HeatmapNet().to(device)
model.to(torch.float16)
print(model)
loss_fn = hungarian_loss

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    model.train()
    total_loss = 0
    for X, y in dataloader:
        X, y = X.to(device), y.to(device)
        pred = model(X)
        loss = loss_fn(pred, y)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        total_loss += loss.item()
    return total_loss / len(dataloader)


def test_loop(dataloader, model, loss_fn):
    model.eval()
    num_batches = len(dataloader)
    test_loss = 0
    all_preds = []

    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            all_preds.append(pred)

    test_loss /= num_batches
    all_preds = torch.cat(all_preds, dim=0)
    return all_preds, test_loss

# %%
'''
X_small = X_train[:2].to(device)
y_small = y_train[:2].to(device)
print(X_small.shape)
print(y_small.shape)

model.train()
pred = model(X_small)
print("Forward:", pred.shape)
print(y_small)
print("X_train  nan:", torch.isnan(X_train).any().item(),  "inf:", torch.isinf(X_train).any().item())
print("y_train  nan:", torch.isnan(y_train_gaussian).any().item(),  "inf:", torch.isinf(y_train_gaussian).any().item())
print("X_test  nan:", torch.isnan(X_test).any().item(),  "inf:", torch.isinf(X_test).any().item())
print("y_test  nan:", torch.isnan(y_test_gaussian).any().item(),  "inf:", torch.isinf(y_test_gaussian).any().item())
print("pred  nan:", torch.isnan(pred).any().item(),  "inf:", torch.isinf(pred).any().item())
print("y     nan:", torch.isnan(y_small).any().item(), "inf:", torch.isinf(y_small).any().item())
loss = hungarian_loss(pred, y_small)
loss.backward()
print("Backward OK, loss:", loss.item())
'''

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)

# %%
import copy
import matplotlib.pyplot as plt
from IPython.display import clear_output

learning_rate = 1e-3
max_epochs = 1000          # generous upper bound; early stopping ends it
patience = 50              # stop after this many epochs with no improvement
min_delta = 1e-4           # improvement smaller than this doesn't count

best_loss = float("inf")
wait = 0
best_state = None
best_epoch = 0

train_losses, test_losses = [], []

loss_fn = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience = 20, factor=0.8)#, verbose=True)

for t in range(max_epochs):
    train_loss = train_loop(train_dataloader, model, loss_fn, optimizer)
    preds, test_loss = test_loop(test_dataloader, model, loss_fn)
    scheduler.step(test_loss)

    train_losses.append(train_loss)
    test_losses.append(test_loss)

    if test_loss < best_loss - min_delta:      # improved
        best_loss = test_loss
        best_epoch = t
        wait = 0
        best_state = copy.deepcopy(model.state_dict())   # snapshot best weights
        torch.save(best_state, output_dir + "best_weight.pth")       # also persist to disk
    else:                                        # no improvement
        wait += 1
        if wait >= patience:
            print(f"Early stopping at epoch {t+1}. "
                  f"Best test loss {best_loss:.4f} at epoch {best_epoch+1}.")
            break
    current_lr = optimizer.param_groups[0]['lr']
    clear_output(wait=True)
    plt.clf() 
    plt.plot(train_losses, label='Train')
    plt.plot(test_losses, label='Test')
    plt.yscale('log')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(f'Epoch {t+1}, Train: {train_loss:.4f}, Test: {test_loss:.4f}, current_lr: {current_lr:.4f}')
    plt.legend()
    plt.show()
# restore the best weights (not the last, possibly-overfit ones)
if best_state is not None:
    model.load_state_dict(best_state)
print("Done!")
torch.save(model.state_dict(), output_dir + "last_weight.pth")
print("weight saved!")
